# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#31 values of x and y
var_x = [1.1, 1.3, 1.5, 2.0, 2.2, 2.9, 3.0, 3.2, 3.2, 3.7, 3.9, 4.0, 4.0, 4.1, 4.5, 4.9, 5.1, 5.3, 5.9, 6.0, 7.9, 8.2, 8.7, 9.0, 9.5, 9.6, 10.3, 10.5, 11.2, 11.5]
var_y = [39343, 46205, 37731, 43525, 39891, 56642, 60150, 54445, 64445, 57189, 63218, 55794, 56957, 57081, 61111, 67938, 66029, 83088, 81363, 93940, 98273, 101302, 113812, 109431, 105582, 116969, 112635, 122391, 121872, 127345]

# %%
print(len(var_x))
print(len(var_y))
# Out:
# 30
# 30

# %%
plt.scatter(var_x, var_y)

# %%
df = pd.DataFrame({'Experience': var_x, '': var_y})
